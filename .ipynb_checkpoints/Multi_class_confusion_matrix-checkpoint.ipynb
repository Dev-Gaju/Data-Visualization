# %% [markdown]
# **Confusion Matrix for Binary Classification**

# %%
from IPython import display
display.Image("C:\\Users\\gazur\\Desktop\\Related Content\\Data Visualization\\Seaborn/two_class.png", height=200, width=500)

# %% [markdown]
# Accuracy =(TP+TN)/(TP+TN+FP+FN)

# %%
Misclassification Rate = (FP+FN)/(TP+TN+FP+FN) or (1-Accuracy)

# %%
Precision = TP/TP+FP

# %%
Recall OR sensitivity = TP/TP+FN

# %%
Specificity = TN/TN+FP

# %%
F1-score: 2 (Precision+recall/precision*recall)

# %% [markdown]
# ### Confusion Matrix for Multi-Class Classification

# %%
from IPython import display
display.Image("C:\\Users\\gazur\\Desktop\\Related Content\\Data Visualization\\Seaborn/confusion_matrix.png", height=200, width=500)

# %% [markdown]
# There are no positive or negative classes here. At first, it might be a little difficult to find TP, TN, FP and FN since there are no positive or negative classes, but it’s actually pretty easy. What we have to do here is to find TP, TN, FP and FN for each individual class.

# %% [markdown]
# For example, if we take class Apple, then let’s see what are the values of the metrics from the confusion matrix.
#
# * TP = 7
# * TN = (2+3+2+1) = 8
# * FP = (8+9) = 17
# * FN = (1+3) = 4

# %% [markdown]
# Since we have all the necessary metrics for class Apple from the confusion matrix, now we can calculate the performance measures for class Apple. For example, class Apple has

# %% [markdown]
# * Precision = 7/(7+17) = 0.29
# * Recall = 7/(7+4) = 0.64
# * F1-score = 0.40
