# %% [markdown]
# Pairplot visualizes given data to find the relationship between them where the variables can be `continuous` or `categorical`.Pairplot is a module of seaborn library which provides a high-level interface for drawing attractive and informative statistical graphics

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set

# %% [markdown]
# **The main-diagonal subplots are the univariate(single feature) histograms (distributions) for each attribute.**

# %% [markdown]
# **Pairplot Parameters:**
# `seaborn.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None, size=None)`

# %%
from IPython import display 
display.Image("C:\\Users\\gazur\\Desktop\\Related Content\\Data Visualization\\Seaborn/Pairplot___description.png",  height=200, width=500)

# %% [markdown]
# In boxplot we can certified the relation ship between two variable.
#
# 1. In first row and 1st colomn see that gausian distribution between total_bils and total_bils.
# 2. In first row and second column we see the relation_shup between total_bils between tip.
#
# as same as it goes on it define the relation.

# %% [markdown]
# https://www.youtube.com/watch?v=uCgvlfIo9fg
